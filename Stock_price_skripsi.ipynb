# %% [markdown]
# <a href="https://colab.research.google.com/github/fadel11-hub/Project-Stock-Price/blob/main/Stock_price_skripsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Dataset

# %%
import kagglehub

# Unduh dataset dari Kaggle
path = kagglehub.dataset_download("brmil07/telecommunications-company-stock-price")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 71.6k/71.6k [00:00<00:00, 19.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/brmil07/telecommunications-company-stock-price/versions/1

# %%
import pandas as pd

# Path ke file CSV di folder dataset yang diunduh
dataset_path = path + "/Stock_TLKM_2005-2024.csv"  # Sesuaikan nama file dengan dataset Anda
df = pd.read_csv(dataset_path)

# Lihat sekilas data
print(df.head(-5))

# # Konversi kolom 'Date' ke format datetime dan set sebagai indeks
# df['Date'] = pd.to_datetime(df['Date'])
# df.set_index('Date', inplace=True)
# Out:
#             Date    Open    High     Low   Close    Adj Close       Volume
# 0     2005-01-26   965.0   975.0   965.0   970.0   548.346130   84725000.0
# 1     2005-01-27   970.0   970.0   960.0   960.0   542.692932  134222500.0
# 2     2005-01-28   965.0   965.0   955.0   960.0   542.692932  100760000.0
# 3     2005-01-31   960.0   965.0   950.0   960.0   542.692932  137322500.0
# 4     2005-02-01   965.0   975.0   960.0   965.0   545.519531   69960000.0
# ...          ...     ...     ...     ...     ...          ...          ...
# 4695  2024-01-17  4000.0  4010.0  3970.0  3990.0  3990.000000   62728400.0
# 4696  2024-01-18  3990.0  4010.0  3930.0  3950.0  3950.000000   73029300.0
# 4697  2024-01-19  3950.0  3960.0  3890.0  3940.0  3940.000000   67016100.0
# 4698  2024-01-22  3980.0  4010.0  3960.0  3980.0  3980.000000   50643700.0
# 4699  2024-01-23  4000.0  4010.0  3910.0  3950.0  3950.000000   72595400.0
#
# [4700 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4705 entries, 0 to 4704
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4705 non-null   object
#  1   Open       4704 non-null   float64
#  2   High       4704 non-null   float64
#  3   Low        4704 non-null   float64
#  4   Close      4704 non-null   float64
#  5   Adj Close  4704 non-null   float64
#  6   Volume     4704 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 257.4+ KB

# %% [markdown]
# # Preprocessing data

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close   Adj Close       Volume
# 0  2005-01-26  965.0  975.0  965.0  970.0  548.346130   84725000.0
# 1  2005-01-27  970.0  970.0  960.0  960.0  542.692932  134222500.0
# 2  2005-01-28  965.0  965.0  955.0  960.0  542.692932  100760000.0
# 3  2005-01-31  960.0  965.0  950.0  960.0  542.692932  137322500.0
# 4  2005-02-01  965.0  975.0  960.0  965.0  545.519531   69960000.0

# %%
df['Date'] = pd.to_datetime(df['Date'].astype(str))
df['Open'] = pd.to_numeric(df['Open'])
df['High'] = pd.to_numeric(df['High'])
df['Low'] = pd.to_numeric(df['Low'])
df['Close'] = pd.to_numeric(df['Close'])
df['Volume'] = pd.to_numeric(df['Volume'])

# %%
df = df[(df['Date'] >= '2019-01-01') & (df['Date'] <= '2024-12-31')]
# Tampilkan data yang sudah difilter
print(df.head())
# Out:
#            Date    Open    High     Low   Close    Adj Close      Volume
# 3452 2019-01-01  3750.0  3750.0  3750.0  3750.0  3102.091309         0.0
# 3453 2019-01-02  3750.0  3760.0  3700.0  3730.0  3085.546875  31355300.0
# 3454 2019-01-03  3710.0  3770.0  3690.0  3740.0  3093.818848  83842400.0
# 3455 2019-01-04  3690.0  3740.0  3690.0  3710.0  3069.002197  73936900.0
# 3456 2019-01-07  3760.0  3790.0  3750.0  3770.0  3118.635498  83678100.0

# %%
df.head()
# Out:
#            Date    Open    High     Low   Close    Adj Close      Volume
# 3452 2019-01-01  3750.0  3750.0  3750.0  3750.0  3102.091309         0.0
# 3453 2019-01-02  3750.0  3760.0  3700.0  3730.0  3085.546875  31355300.0
# 3454 2019-01-03  3710.0  3770.0  3690.0  3740.0  3093.818848  83842400.0
# 3455 2019-01-04  3690.0  3740.0  3690.0  3710.0  3069.002197  73936900.0
# 3456 2019-01-07  3760.0  3790.0  3750.0  3770.0  3118.635498  83678100.0

# %%
df.isna().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
# Locate NaN values in the 'Price' column
nan_rows = df[df['Volume'].isna()]
print(nan_rows)
# Out:
#            Date  Open  High  Low  Close  Adj Close  Volume
# 3573 2019-06-19   NaN   NaN  NaN    NaN        NaN     NaN

# %%
# Drop rows with any null values
df.dropna(inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# ## Normalisasi data

# %%
from sklearn.preprocessing import MinMaxScaler

# Pisahkan kolom 'Date' dan data numerik
date_column = df['Date']
numerical_df = df.drop(columns=['Date'])

# # Konversi kolom numerik menjadi tipe numerik (jika belum)
# numerical_df = numerical_df.apply(pd.to_numeric)

numerical_df.head()
# Out:
#         Open    High     Low   Close    Adj Close      Volume
# 3452  3750.0  3750.0  3750.0  3750.0  3102.091309         0.0
# 3453  3750.0  3760.0  3700.0  3730.0  3085.546875  31355300.0
# 3454  3710.0  3770.0  3690.0  3740.0  3093.818848  83842400.0
# 3455  3690.0  3740.0  3690.0  3710.0  3069.002197  73936900.0
# 3456  3760.0  3790.0  3750.0  3770.0  3118.635498  83678100.0

# %%
# Inisialisasi MinMaxScaler untuk normalisasi
scaler = MinMaxScaler()

# Normalisasi kolom numerik
scaled_data = scaler.fit_transform(numerical_df)

# Mengubah hasil normalisasi kembali ke DataFrame dengan nama kolom yang sesuai
scaled_df = pd.DataFrame(scaled_data, columns=numerical_df.columns)

# # Gabungkan kembali kolom 'Date' dengan DataFrame yang sudah dinormalisasi
# scaled_df['Date'] = date_column

# Tampilkan hasil
print(scaled_df.head())
# Out:
#        Open      High       Low     Close  Adj Close    Volume
# 0  0.521739  0.513274  0.572687  0.538462   0.383278  0.000000
# 1  0.521739  0.517699  0.550661  0.529412   0.376270  0.027127
# 2  0.504348  0.522124  0.546256  0.533937   0.379774  0.072537
# 3  0.495652  0.508850  0.546256  0.520362   0.369263  0.063967
# 4  0.526087  0.530973  0.572687  0.547511   0.390285  0.072395

# %%
# Cek apakah ada nilai yang menjadi NaT setelah konversi
if date_column.isna().sum() > 0:
    print(f"Ada {date_column.isna().sum()} nilai yang tidak valid di kolom 'Date'.")

print(date_column.head())
# Out:
# 3452   2019-01-01
# 3453   2019-01-02
# 3454   2019-01-03
# 3455   2019-01-04
# 3456   2019-01-07
# Name: Date, dtype: datetime64[ns]

# %%
# Gabungkan kembali kolom 'Date' dengan DataFrame yang sudah dinormalisasi
scaled_df['Date'] = date_column

scaled_df.head()
# Out:
#        Open      High       Low     Close  Adj Close    Volume Date
# 0  0.521739  0.513274  0.572687  0.538462   0.383278  0.000000  NaT
# 1  0.521739  0.517699  0.550661  0.529412   0.376270  0.027127  NaT
# 2  0.504348  0.522124  0.546256  0.533937   0.379774  0.072537  NaT
# 3  0.495652  0.508850  0.546256  0.520362   0.369263  0.063967  NaT
# 4  0.526087  0.530973  0.572687  0.547511   0.390285  0.072395  NaT

# %% [markdown]
# # Build model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Dropout

# Membangun model
model = Sequential([
    Bidirectional(LSTM(100, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))),
    Dropout(0.2),
    Bidirectional(LSTM(50)),
    Dropout(0.2),
    Dense(1)
])

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# %%
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Prediksi pada data train dan test
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inversi skala
train_predict = scaler.inverse_transform(
    np.concatenate((train_predict, np.zeros((train_predict.shape[0], data_scaled.shape[1] - 1))), axis=1)
)[:, 0]
test_predict = scaler.inverse_transform(
    np.concatenate((test_predict, np.zeros((test_predict.shape[0], data_scaled.shape[1] - 1))), axis=1)
)[:, 0]

y_train_actual = scaler.inverse_transform(
    np.concatenate((y_train.reshape(-1, 1), np.zeros((y_train.shape[0], data_scaled.shape[1] - 1))), axis=1)
)[:, 0]
y_test_actual = scaler.inverse_transform(
    np.concatenate((y_test.reshape(-1, 1), np.zeros((y_test.shape[0], data_scaled.shape[1] - 1))), axis=1)
)[:, 0]

# Evaluasi RMSE
train_rmse = np.sqrt(mean_squared_error(y_train_actual, train_predict))
test_rmse = np.sqrt(mean_squared_error(y_test_actual, test_predict))

print(f"Train RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")

# %%
# Visualisasi prediksi
plt.figure(figsize=(14, 6))
plt.plot(df.index[:len(y_train_actual)], y_train_actual, label='Actual Train Data')
plt.plot(df.index[len(y_train_actual):len(y_train_actual) + len(y_test_actual)], y_test_actual, label='Actual Test Data')
plt.plot(df.index[len(y_train_actual):len(y_train_actual) + len(test_predict)], test_predict, label='Predicted Data')
plt.legend()
plt.title("BiDirectional LSTM Stock Price Prediction (All Variables)")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.show()
